# %% [markdown]
# You can install keras independently or you can use the one that comes with tensorflow

# %%
import pandas as pd
import numpy as np
import keras
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %% [markdown]
# ### Loading dataset

# %%
data = pd.read_csv('./../data/wine-quality/winequality-white.csv', sep=';')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
data.shape
# Out:
# (4898, 12)

# %% [markdown]
# There will be 11 input features

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %% [markdown]
# #### Checking for any NaN entry

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Data is clean

# %% [markdown]
# #### Sepearting features and labels

# %%
data_cols = data.columns
features = data[data_cols[data_cols != 'quality']]
n_cols = features.shape[1]
target = data['quality']

# %%
features.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9

# %% [markdown]
# ### Normalising the features

# %%
features = (features - features.mean())/features.std()
features.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.172079         -0.081762     0.213258        2.821061  -0.035351
# 1      -0.657434          0.215874     0.047996       -0.944669   0.147732
# 2       1.475600          0.017450     0.543783        0.100272   0.193503
# 3       0.409083         -0.478608    -0.117266        0.415726   0.559670
# 4       0.409083         -0.478608    -0.117266        0.415726   0.559670
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.569873              0.744489  2.331274 -1.246794  -0.349149
# 1            -1.252891             -0.149669 -0.009153  0.739953   0.001342
# 2            -0.312109             -0.973236  0.358628  0.475053  -0.436771
# 3             0.687471              1.120977  0.525802  0.011479  -0.787262
# 4             0.687471              1.120977  0.525802  0.011479  -0.787262
#
#     alcohol
# 0 -1.393010
# 1 -0.824192
# 2 -0.336633
# 3 -0.499152
# 4 -0.499152

# %%
target.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: quality, dtype: int64

# %%
n_cols
# Out:
# 11

# %% [markdown]
# #### Dividing the data into train and test sets

# %%
from sklearn.model_selection import train_test_split

features_train, features_test, target_train, target_test = train_test_split(features, target,
                                                                            test_size=0.20, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ### Building a Sequential Model

# %%
def regression():
    model = Sequential()
    # Adding layers to the Neural Network
    # 2 Hindden Layers each of 5 Relu units
    # 1 output unit Output Layer
    model.add(Dense(5, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(5, activation='relu'))
    model.add(Dense(1))
    #Using ADAM optimizer does not requires passing learning rate
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ### Training the model

# %%
model = regression()
history = model.fit(features_train, target_train, validation_split=0.3, epochs=100, verbose=2)
# Out:
# WARNING:tensorflow:From /home/akshay/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 2742 samples, validate on 1176 samples
# Epoch 1/100
#  - 0s - loss: 34.6118 - val_loss: 31.5625
# Epoch 2/100
#  - 0s - loss: 29.3618 - val_loss: 26.6108
# Epoch 3/100
#  - 0s - loss: 24.4732 - val_loss: 22.2024
# Epoch 4/100
#  - 0s - loss: 20.5925 - val_loss: 18.6881
# Epoch 5/100
#  - 0s - loss: 16.7654 - val_loss: 14.6903
# Epoch 6/100
#  - 0s - loss: 12.6927 - val_loss: 10.8729
# Epoch 7/100
#  - 0s - loss: 9.1121 - val_loss: 7.6491
# Epoch 8/100
#  - 0s - loss: 6.3115 - val_loss: 5.3415
# Epoch 9/100
#  - 0s - loss: 4.5352 - val_loss: 3.9632
# Epoch 10/100
#  - 0s - loss: 3.3915 - val_loss: 2.9839
# Epoch 11/100
#  - 0s - loss: 2.5554 - val_loss: 2.2726
# Epoch 12/100
#  - 0s - loss: 1.9500 - val_loss: 1.7824
# Epoch 13/100
#  - 0s - loss: 1.5566 - val_loss: 1.4792
# Epoch 14/100
#  - 0s - loss: 1.3115 - val_loss: 1.2900
# Epoch 15/100
#  - 0s - loss: 1.1464 - val_loss: 1.1525
# Epoch 16/100
#  - 0s - loss: 1.0240 - val_loss: 1.0479
# Epoch 17/100
#  - 0s - loss: 0.9283 - val_loss: 0.9629
# Epoch 18/100
#  - 0s - loss: 0.8507 - val_loss: 0.8977
# Epoch 19/100
#  - 0s - loss: 0.7866 - val_loss: 0.8448
# Epoch 20/100
#  - 0s - loss: 0.7380 - val_loss: 0.8018
# Epoch 21/100
#  - 0s - loss: 0.6994 - val_loss: 0.7673
# Epoch 22/100
#  - 0s - loss: 0.6685 - val_loss: 0.7412
# Epoch 23/100
#  - 0s - loss: 0.6441 - val_loss: 0.7192
# Epoch 24/100
#  - 0s - loss: 0.6245 - val_loss: 0.6980
# Epoch 25/100
#  - 0s - loss: 0.6090 - val_loss: 0.6832
# Epoch 26/100
#  - 0s - loss: 0.5956 - val_loss: 0.6707
# Epoch 27/100
#  - 0s - loss: 0.5873 - val_loss: 0.6583
# Epoch 28/100
#  - 0s - loss: 0.5801 - val_loss: 0.6479
# Epoch 29/100
#  - 0s - loss: 0.5742 - val_loss: 0.6444
# Epoch 30/100
#  - 0s - loss: 0.5696 - val_loss: 0.6339
# Epoch 31/100
#  - 0s - loss: 0.5656 - val_loss: 0.6332
# Epoch 32/100
#  - 0s - loss: 0.5627 - val_loss: 0.6251
# Epoch 33/100
#  - 0s - loss: 0.5590 - val_loss: 0.6211
# Epoch 34/100
#  - 0s - loss: 0.5561 - val_loss: 0.6165
# Epoch 35/100
#  - 0s - loss: 0.5527 - val_loss: 0.6157
# Epoch 36/100
#  - 0s - loss: 0.5509 - val_loss: 0.6104
# Epoch 37/100
#  - 0s - loss: 0.5495 - val_loss: 0.6076
# Epoch 38/100
#  - 0s - loss: 0.5472 - val_loss: 0.6046
# Epoch 39/100
#  - 0s - loss: 0.5456 - val_loss: 0.6059
# Epoch 40/100
#  - 0s - loss: 0.5440 - val_loss: 0.6000
# Epoch 41/100
#  - 0s - loss: 0.5419 - val_loss: 0.5979
# Epoch 42/100
#  - 0s - loss: 0.5405 - val_loss: 0.5955
# Epoch 43/100
#  - 0s - loss: 0.5385 - val_loss: 0.5942
# Epoch 44/100
#  - 0s - loss: 0.5363 - val_loss: 0.5936
# Epoch 45/100
#  - 0s - loss: 0.5363 - val_loss: 0.5926
# Epoch 46/100
#  - 0s - loss: 0.5345 - val_loss: 0.5883
# Epoch 47/100
#  - 0s - loss: 0.5329 - val_loss: 0.5882
# Epoch 48/100
#  - 0s - loss: 0.5307 - val_loss: 0.5823
# Epoch 49/100
#  - 0s - loss: 0.5291 - val_loss: 0.5799
# Epoch 50/100
#  - 0s - loss: 0.5257 - val_loss: 0.5772
# Epoch 51/100
#  - 0s - loss: 0.5241 - val_loss: 0.5724
# Epoch 52/100
#  - 0s - loss: 0.5192 - val_loss: 0.5717
# Epoch 53/100
#  - 0s - loss: 0.5153 - val_loss: 0.5688
# Epoch 54/100
#  - 0s - loss: 0.5119 - val_loss: 0.5649
# Epoch 55/100
#  - 0s - loss: 0.5098 - val_loss: 0.5665
# Epoch 56/100
#  - 0s - loss: 0.5087 - val_loss: 0.5614
# Epoch 57/100
#  - 0s - loss: 0.5058 - val_loss: 0.5648
# Epoch 58/100
#  - 0s - loss: 0.5062 - val_loss: 0.5629
# Epoch 59/100
#  - 0s - loss: 0.5029 - val_loss: 0.5615
# Epoch 60/100
#  - 0s - loss: 0.5007 - val_loss: 0.5580
# Epoch 61/100
#  - 0s - loss: 0.5003 - val_loss: 0.5568
# Epoch 62/100
#  - 0s - loss: 0.4995 - val_loss: 0.5564
# Epoch 63/100
#  - 0s - loss: 0.4976 - val_loss: 0.5592
# Epoch 64/100
#  - 0s - loss: 0.4957 - val_loss: 0.5599
# Epoch 65/100
#  - 0s - loss: 0.4948 - val_loss: 0.5581
# Epoch 66/100
#  - 0s - loss: 0.4946 - val_loss: 0.5551
# Epoch 67/100
#  - 0s - loss: 0.4951 - val_loss: 0.5574
# Epoch 68/100
#  - 0s - loss: 0.4940 - val_loss: 0.5569
# Epoch 69/100
#  - 0s - loss: 0.4917 - val_loss: 0.5554
# Epoch 70/100
#  - 0s - loss: 0.4929 - val_loss: 0.5563
# Epoch 71/100
#  - 0s - loss: 0.4902 - val_loss: 0.5561
# Epoch 72/100
#  - 0s - loss: 0.4895 - val_loss: 0.5570
# Epoch 73/100
#  - 0s - loss: 0.4896 - val_loss: 0.5572
# Epoch 74/100
#  - 0s - loss: 0.4897 - val_loss: 0.5549
# Epoch 75/100
#  - 0s - loss: 0.4871 - val_loss: 0.5565
# Epoch 76/100
#  - 0s - loss: 0.4873 - val_loss: 0.5553
# Epoch 77/100
#  - 0s - loss: 0.4879 - val_loss: 0.5574
# Epoch 78/100
#  - 0s - loss: 0.4854 - val_loss: 0.5533
# Epoch 79/100
#  - 0s - loss: 0.4870 - val_loss: 0.5604
# Epoch 80/100
#  - 0s - loss: 0.4868 - val_loss: 0.5545
# Epoch 81/100
#  - 0s - loss: 0.4862 - val_loss: 0.5578
# Epoch 82/100
#  - 0s - loss: 0.4862 - val_loss: 0.5564
# Epoch 83/100
#  - 0s - loss: 0.4849 - val_loss: 0.5531
# Epoch 84/100
#  - 0s - loss: 0.4840 - val_loss: 0.5561
# Epoch 85/100
#  - 0s - loss: 0.4834 - val_loss: 0.5628
# Epoch 86/100
#  - 0s - loss: 0.4838 - val_loss: 0.5576
# Epoch 87/100
#  - 0s - loss: 0.4830 - val_loss: 0.5563
# Epoch 88/100
#  - 0s - loss: 0.4815 - val_loss: 0.5624
# Epoch 89/100
#  - 0s - loss: 0.4841 - val_loss: 0.5556
# Epoch 90/100
#  - 0s - loss: 0.4819 - val_loss: 0.5557
# Epoch 91/100
#  - 0s - loss: 0.4826 - val_loss: 0.5544
# Epoch 92/100
#  - 0s - loss: 0.4830 - val_loss: 0.5565
# Epoch 93/100
#  - 0s - loss: 0.4824 - val_loss: 0.5553
# Epoch 94/100
#  - 0s - loss: 0.4824 - val_loss: 0.5579
# Epoch 95/100
#  - 0s - loss: 0.4822 - val_loss: 0.5562
# Epoch 96/100
#  - 0s - loss: 0.4816 - val_loss: 0.5577
# Epoch 97/100
#  - 0s - loss: 0.4835 - val_loss: 0.5562
# Epoch 98/100
#  - 0s - loss: 0.4814 - val_loss: 0.5570
# Epoch 99/100
#  - 0s - loss: 0.4811 - val_loss: 0.5552
# Epoch 100/100
#  - 0s - loss: 0.4823 - val_loss: 0.5554

# %%
hist = pd.DataFrame(history.history)
hist
# Out:
#      val_loss       loss
# 0   31.562458  34.611848
# 1   26.610848  29.361763
# 2   22.202427  24.473207
# 3   18.688136  20.592501
# 4   14.690305  16.765363
# ..        ...        ...
# 95   0.557736   0.481577
# 96   0.556243   0.483476
# 97   0.556976   0.481393
# 98   0.555161   0.481101
# 99   0.555427   0.482330
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Plotting training versur Validation Loss
# The two loss curves and the final loss values should be almost identical.

# %%
plt.figure(figsize=(8,6))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Vs Validataion Loss')
sns.lineplot(history.epoch, hist.loss, label='Training Loss')
sns.lineplot(history.epoch, hist.val_loss, label='Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Testing the model

# %%
#model.evaluate returns test loss or list of scalars (if the model has multiple outputs and/or metrics)
evaluation = model.evaluate(features_test, target_test)
evaluation
# Out:
# 980/980 [==============================] - 0s 27us/step
# 0.5075794592195627

# %% [markdown]
# Since the test_loss: 0.5502 is close to training_loss: 0.480829 and validation_loss: 0.5693
